# %% [markdown]
# # Phase 11: Guardrail & Grounding Evaluation
#
# ## Objective
# Evaluate input guardrails, low-confidence retrieval abstention, hallucination prevention, and false-refusal rates.

# %%
from src.guardrails.grounding_validator import GroundingValidator

validator = GroundingValidator()
ans = "मैनहट्टन परियोजना ने पहला परमाणु हथियार बनाया।"
ctx = ["मैनहट्टन परियोजना द्वितीय विश्व युद्ध के दौरान एक शोध और विकास उपक्रम था जिसने पहले परमाणु हथियारों का निर्माण किया।"]

res = validator.validate_answer_grounding(ans, ctx)
print("Grounding Validation Result:", res)
